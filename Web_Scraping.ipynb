# %% [markdown]
# # General Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

html_text = requests.get('https://community.infineon.com/?profile.language=en').text
soup = BeautifulSoup(html_text, 'lxml')

product_types = soup.find_all('a', class_='board-link')

data = []
        
for index, product_type in enumerate(product_types):
    # Find the title, body and time elements within the specific product type
    title = product_type.find_next('div', class_='subject').text.strip()
    body = product_type.find_next('div', class_='full-body body').text.strip()
    time = product_type.find_next('span', class_='time').text.strip().replace(' ', '')
    
    # link
    raw_link = product_type["href"]
    domain_link = 'https://community.infineon.com'
    link = domain_link + raw_link
    
    data.append({
        'product_types': product_type.text.strip(),
        'Title': title,
        'Body': body,
        'Time': time,
        'forum link': link
    })

df = pd.DataFrame(data)
df
# Out:
#                      product_types  \
# 0                             IGBT
# 1                      TRAVEO™ T2G
# 2                           AURIX™
# 3                  Gate Driver ICs
# 4  Intelligent Power Modules (IPM)
# 5           Battery Management ICs
# 6                          PSoC™ 6
# 7                          PSoC™ 6
# 8                       MOTIX™ MCU
# 9       USB superspeed peripherals
#
#                                                Title  \
# 0                                               驱动芯片
# 1                                           S6J32HEL
# 2  Performance comparison between TC399XX and TRA...
# 3  Controlling AC load with two mosfets and 1ED31...
# 4  Three Phase Sine Wave Power Supply using CIPOS...
# 5  hello nice to see you all today eggsoil\n\n\n ...
# 6  Encountering Issues with Programming and Debug...
# 7  使用PSoc 62系列板卡时遇到了无法烧录和调试的问题，似乎是flash的问题\n\n\n ...
# 8         Question of Angel PLL observer (MOTIX FOC)
# 9                                          我有一些问题请教你
#
#                                                 Body       Time  \
# 0  Hello , i need to know which tool can flash re...  May5,2024
# 1  Hello , i need to know which tool can flash re...  May5,2024
# 2  Hello,\nDo you have any benchmark that compare...  May4,2024
# 3  Hi,I am investigating the possibility of contr...  May4,2024
# 4  Hi all,I am an Embedded Engineer and I am look...  May4,2024
# 5  hello nice to see you all today eggsoil\nhttps...  May4,2024
# 6  Translated Content:\nBoard Model: Psoc6-evalua...  May4,2024
# 7  我的板卡型号是Psoc6-evaluationkit-062S2，在我按下板卡上的MODE按...  May4,2024
# 8  Hi all, I met some questions when I worked wit...  May3,2024
# 9  Hello,I have a CYUSBKIT-003 board and I am stu...  May3,2024
#
#                                           forum link
# 0   https://community.infineon.com/t5/IGBT/bd-p/IGBT
# 1  https://community.infineon.com/t5/TRAVEO-T2G/b...
# 2  https://community.infineon.com/t5/AURIX/bd-p/A...
# 3  https://community.infineon.com/t5/Gate-Driver-...
# 4  https://community.infineon.com/t5/Intelligent-...
# 5  https://community.infineon.com/t5/Battery-Mana...
# 6  https://community.infineon.com/t5/PSoC-6/bd-p/...
# 7  https://community.infineon.com/t5/PSoC-6/bd-p/...
# 8  https://community.infineon.com/t5/MOTIX-MCU/bd...
# 9  https://community.infineon.com/t5/USB-superspe...

# %%
options = soup.find_all('li', class_='options')

print(f'Number of Types: {len(options)} \n')

data2 = []

for option in options:
    temp = option.text.strip()
    data2.append({'product_types': temp})
    
df_product = pd.DataFrame(data2)
df_product
# Out:
# Number of Types: 72
#                           product_types
# 0                               PSoC™ 6
# 1                           Wi-Fi Combo
# 2                             Nor Flash
# 3   USB low-full-high speed peripherals
# 4      FIRST Robotics Competition (FRC)
# ..                                  ...
# 67                 Power Management ICs
# 68                           MOTIX™ MCU
# 69              Legacy microcontrollers
# 70               Battery Management ICs
# 71    Contactless power and sensing ICs
#
# [72 rows x 1 columns]

# %% [markdown]
# # Extend our web scraping according to the product
# For example, IGBT...

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# Define the base URL for the first page
base_url = 'https://community.infineon.com/t5/IGBT/bd-p/IGBT'

data3 = []

# Define the number of pages you want to scrape
num_pages = 3  # Modify this according to your requirements

for page in range(num_pages):
    if page == 0:
        url = base_url
    else:
        # Construct the URL for the current page
        url = f'{base_url}/page/{page+1}'
    
    # Request HTML content
    html_text = requests.get(url).text
    soup = BeautifulSoup(html_text, 'lxml')
    
    # Find all product types on the current page
    product_types = soup.find_all('a', class_='board-link')
    
    for product_type in product_types:
        # Find the title, body, and time elements within the specific product type
        title = product_type.find_next('div', class_='subject').text.strip()
        body = product_type.find_next('div', class_='full-body body').text.strip()
        time = product_type.find_next('span', class_='time').text.strip().replace(' ', '')
        
        data3.append({
            'product_types': product_type.text.strip(),
            'Title': title,
            'Body': body,
            'Time': time
        })

# Create DataFrame
df_IGBT = pd.DataFrame(data3)
df_IGBT
# Out:
#    product_types                                              Title  \
# 0           IGBT                                               驱动芯片
# 1           IGBT                Differents housing for igbt modules
# 2           IGBT        Question about Infineon’s Simulation Models
# 3           IGBT                                    Eval-M1-CM610N3
# 4           IGBT  IKCM30F60GD , what is the max output current @...
# 5           IGBT  IFCM20U65GD IPM module inexplicably shuts down...
# 6           IGBT           Automotive Grade IGBT Module Reliability
# 7           IGBT                 IGBT model\n\n\n            Solved
# 8           IGBT                                            3KW炸机问题
# 9           IGBT      Eval-M1-CM610N3 评估板电源\n\n\n            Solved
# 10          IGBT                          short-circuit oscillation
# 11          IGBT  IGBT HTRB 可靠性测试时结温Tvj=175°C怎么测量\n\n\n         ...
# 12          IGBT                        Basic Gate Driver Questions
# 13          IGBT  IGBT part number decoder - what do the letters...
# 14          IGBT       FF3MR20KM1H forward bias safe operating area
# 15          IGBT                igbt module\n\n\n            Solved
# 16          IGBT  Questions about the PressFit process\n\n\n    ...
# 17          IGBT                  IGBT动静态特性\n\n\n            Solved
# 18          IGBT  三电平NPCIGBT功率模块选型推荐，及其对应的驱动芯片选型。\n\n\n         ...
# 19          IGBT  Adapting Induction EVAL-kit to 400V 3-phase 16...
# 20          IGBT  Can the ground of the thermistor in FS3L40R07W...
# 21          IGBT  Basic Gate Driver Questions\n\n\n            S...
# 22          IGBT           power simulation\n\n\n            Solved
# 23          IGBT                   IGBT栅极驱动\n\n\n            Solved
# 24          IGBT  SOA query on IGBT shutdown\n\n\n            So...
# 25          IGBT                   驱动芯片发烫严重\n\n\n            Solved
# 26          IGBT  External NTC position for sense temperature of...
# 27          IGBT  Kit Hybridpack DSC S2 Software Updates\n\n\n  ...
# 28          IGBT    What is the principle of the following topology
# 29          IGBT  Limitations on the maximum current of the SOA ...
#
#                                                  Body        Time
# 0   Hello, \nI am learning about all the infineon'...   May5,2024
# 1   Hello, \nI am learning about all the infineon'...  Apr30,2024
# 2   Hello! I am trying to use the PLECS thermal mo...   May2,2024
# 3   Regarding the principle provided in the thread...  Apr30,2024
# 4   IFCM20U65GD IPM module has normal VFO pin, nor...  Apr20,2024
# 5   IFCM20U65GD IPM module has normal VFO pin, nor...  Apr30,2024
# 6   Hello, I didn't find any quality report about ...  Apr26,2024
# 7   您好，各位工程师，我们在测试3KW功率板的时候出现炸机问题，我们猜测是过电压或过电流导致，如...  Apr27,2024
# 8   您好，各位工程师，我们在测试3KW功率板的时候出现炸机问题，我们猜测是过电压或过电流导致，如...  Apr24,2024
# 9   hi\n工程师\nU2 D 和S直接之间的线宽我用的120mil, 四个S我也是用120mi...  Apr17,2024
# 10  What is the relationship between short-circuit...  Apr25,2024
# 11  This is in regards to 1ED3124MC12H (https://ww...  Apr26,2024
# 12  This is in regards to 1ED3124MC12H (https://ww...  Apr22,2024
# 13  Where are the various types of IGBTs defined?\...  Apr26,2024
# 14  I am working on a wireless charger for electri...  Apr23,2024
# 15  Good afternoon, would it be possible to replac...  Apr24,2024
# 16  Hello everyone, my board needs to use a SmartP...  Apr23,2024
# 17  您好， （1）目前的驱动芯片：1ED020I12-F2（2A），IGBT模块：FS3L50R...  Apr23,2024
# 18  您好， （1）目前的驱动芯片：1ED020I12-F2（2A），IGBT模块：FS3L50R...  Apr18,2024
# 19  We're working on several induction systems for...  Apr17,2024
# 20  smartconx_target@Q!w2e3r4t5y6u7i8o9p0||/t5/IGB...  Apr22,2024
# 21  This is in regards to 1ED3124MC12H trying to d...  Apr22,2024
# 22  Hey guys, the following topology is a DC/AC ap...  Apr21,2024
# 23  您好：\n         现在我们在用贵公司的1ED020I12-F2芯片，但是出现了一个...  Apr18,2024
# 24  IGBT will cut off the high current when shutti...  Apr17,2024
# 25  给驱动芯片供电的DC-DC模块正常，IGBT模块是F3L200R12W2H3_B11，驱动芯...  Apr16,2024
# 26  Dear community members\nI need to measure the ...  Apr16,2024
# 27  Hi,\nOur company recently bought a Hybrid Kit ...  Apr10,2024
# 28  Hydrogen production power supply front-end top...  Apr15,2024
# 29  Recently we need to develop a batch of IGBT de...  Apr14,2024

# %% [markdown]
# # Explore Input Data

# %% [markdown]
# According to different product, we have different input data. To simplify the process, we could use "Instant Data Scraper" chrome extension to do data scraping from the community website. (https://chromewebstore.google.com/detail/instant-data-scraper/ofaokhiedipichpaobibbnahnkdoiiah)

# %%
df1 = pd.read_csv('data/PSoC6.csv')
df2 = pd.read_csv('data/Wi-Fi Combo.csv')
df3 = pd.read_csv('data/Nor Flash.csv')
df4 = pd.read_csv('data/USB low-full-high speed peripherals.csv')
df5 = pd.read_csv('data/MOSFET.csv')

# %%
df1.loc[:,['board-link','subject-link','truncated-body']].head() #PSoC6
# Out:
#   board-link                                       subject-link  \
# 0    PSoC™ 6            使用PSoc 62系列板卡时遇到了无法烧录和调试的问题，似乎是flash的问题
# 1    PSoC™ 6                                PSoC6 CY8CPROTO-063
# 2    PSoC™ 6  Encountering Issues with Programming and Debug...
# 3    PSoC™ 6         SCB Managing Slave Select Peripheral Lines
# 4    PSoC™ 6  How to properly use dma and spi together with ...
#
#                                       truncated-body
# 0  我的板卡型号是Psoc6-evaluationkit-062S2，在我按下板卡上的MODE按...
# 1  Hello, good afternoon, I am going to work on a...
# 2  Translated Content:\nBoard Model: Psoc6-evalua...
# 3  - Device Configurator 3.10.0.6117\n- 7e6892ee1...
# 4  We are having a problem communicating with two...

# %%
df2.loc[:,['board-link','subject-link','truncated-body']].head() #Wi-Fi Combo
# Out:
#     board-link                                       subject-link  \
# 0  Wi-Fi Combo                            Malloc is thread safe ?
# 1  Wi-Fi Combo            CYW943907 - Amazon FreeRTOS OTA support
# 2  Wi-Fi Combo  how to enable or disable the save restore feat...
# 3  Wi-Fi Combo                                HTTPS speed problem
# 4  Wi-Fi Combo                                Disable dns server.
#
#                                       truncated-body
# 0  Hello,\nI'm using WICED STUDIO 6.6. and CYW943...
# 1  Hi, Per Amazon doc, CYW943907AEVAL1F is not su...
# 2  when I read the register of CHIPCOMMON_SR_CONT...
# 3  Good afternoon. I am facing HTTPS speed issue ...
# 4  Hi, I have a Laird Sterling EWB. What I try to...

# %%
df3.loc[:,['board-link','subject-link','truncated-body']].head() #Nor Flash
# Out:
#   board-link                                       subject-link  \
# 0  Nor Flash  how to use or unprotect the highest address se...
# 1  Nor Flash          S25FL256LAGNFM010 material specifications
# 2  Nor Flash                    S29AL016J70TFN020 Thermal Data?
# 3  Nor Flash             Where is the file ---- slld_fll_256l.h
# 4  Nor Flash                S29JL032J60TFI010 of Product Status
#
#                                       truncated-body
# 0  Hi,\nIam using a  S70GL02GT11FHA010 NOR Flash....
# 1  I would like to know what the potting compound...
# 2  Hello,\nWe would like to use this memory: S29A...
# 3  A member from Infineon posted me a zip file re...
# 4  How is the production of S29JL032J60TFI010 pro...

# %%
df4.loc[:,['board-link','subject-link','truncated-body']].head() #USB low-full-high speed peripherals
# Out:
#                             board-link  \
# 0  USB low-full-high speed peripherals
# 1  USB low-full-high speed peripherals
# 2  USB low-full-high speed peripherals
# 3  USB low-full-high speed peripherals
# 4  USB low-full-high speed peripherals
#
#                                      subject-link  \
# 0              CY7C65215, configuration image CRC
# 1  Arming of bulk/interrupt out endpoint in fx2lp
# 2      Pinout error on documentation of CY7C6514D
# 3                            CY7C65210 TID Number
# 4    Setting up isochronous out endpoint in fx2lp
#
#                                       truncated-body
# 0  From a linux system, I want to read back the c...
# 1  Hello,I am stuck at a point,in my application ...
# 2  Hi Infineon Community,\nI am reviewing the sec...
# 3      Hi,\nWhat is CY7C65210 TID number?\nBR\nEason
# 4  Hello,Can someone point me to examples codes f...

# %%
df5.loc[:,['subject-link','truncated-body']].head() # MOSFET # No feature 'board-link'
# Out:
#                                     subject-link  \
# 0                              Double Pulse Test
# 1                                       TCC data
# 2                   Cu Clip in Automotive Mosfet
# 3  SiC IMBG120R350M1HXTMA1 sense pin unconnected
# 4                                  EVAL Inverter
#
#                                       truncated-body
# 0  In the datasheet, a dual pulse test circuit wa...
# 1  Hello,\nI am reaching out to request TCC data ...
# 2  Hi\n \nDoes infineon has Cu Clip technology in...
# 3  Hello together,\nI'm planning to use a SiC IMB...
# 4  I'm playing around with the EVAL_3K3W_TP_PFC_S...
