# %% [markdown]
# # Web Scraping

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

html_text = requests.get('https://community.infineon.com/?profile.language=en').text
soup = BeautifulSoup(html_text, 'lxml')

titles = soup.find_all('div', class_='subject')

data = []

for index, title in enumerate(titles):
    # Find the body and time elements within the specific title
    body = title.find_next('div', class_='full-body body').text.strip()
    time = title.find_next('span', class_='time').text.strip().replace(' ', '')

    data.append({
        'Title': title.text.strip(),
        'Body': body,
        'Time': time
    })

df = pd.DataFrame(data)

# Save DataFrame to CSV
df.to_csv('infineon_community.csv', index=False)
df
# Out:
#                                                Title  \
# 0  Performance comparison between TC399XX and TRA...
# 1  Controlling AC load with two mosfets and 1ED31...
# 2  Three Phase Sine Wave Power Supply using CIPOS...
# 3  hello nice to see you all today eggsoil\n\n\n ...
# 4  Encountering Issues with Programming and Debug...
# 5  使用PSoc 62系列板卡时遇到了无法烧录和调试的问题，似乎是flash的问题\n\n\n ...
# 6         Question of Angel PLL observer (MOTIX FOC)
# 7                                          我有一些问题请教你
# 8          Unlock the thread\n\n\n            Solved
# 9                                PSoC6 CY8CPROTO-063
#
#                                                 Body       Time
# 0  Hello,\nDo you have any benchmark that compare...  May4,2024
# 1  Hi,I am investigating the possibility of contr...  May4,2024
# 2  Hi all,I am an Embedded Engineer and I am look...  May4,2024
# 3  hello nice to see you all today eggsoil\nhttps...  May4,2024
# 4  Translated Content:\nBoard Model: Psoc6-evalua...  May4,2024
# 5  我的板卡型号是Psoc6-evaluationkit-062S2，在我按下板卡上的MODE按...  May4,2024
# 6  Hi all, I met some questions when I worked wit...  May3,2024
# 7  Hello,I have a CYUSBKIT-003 board and I am stu...  May3,2024
# 8  May I have my recent thread unlocked. I need s...  May3,2024
# 9  Hello, good afternoon, I am going to work on a...  May3,2024

# %%
options = soup.find_all('li', class_='options')

print(f'Number of Types: {len(options)} \n')

print(f'Type: \n')
for option in options:
    print(option.text.strip())
# Out:
# Number of Types: 72
#
# Type:
#
# PSoC™ 6
# Wi-Fi Combo
# Nor Flash
# USB low-full-high speed peripherals
# FIRST Robotics Competition (FRC)
# MOSFET (Si/SiC)
# Adapters and Chargers
# RF Transistors
# OPTIGA™ Trust
# CIRRENT™ Product Analytics
# AIROC™ Wi-Fi and Wi-Fi Bluetooth Combos
# CO₂ sensor
# Community Information
# Studio Bluetooth
# Clocks
# Hyper Flash
# Robotics
# USB hosts hubs transceivers
# OPTIGA™ TPM
# 3D Hall (Magnetic sensor)
# CIRRENT™ Cloud ID
# AIROC™ Wi-Fi MCUs
# IGBT
# PSoC™ 4
# Smart Bluetooth
# Other Technologies General
# Hyper RAM
# USB superspeed peripherals
# ModusToolbox™
# GaN
# SECORA™ Blockchain
# Antenna tuners
# Switches (Magnetic sensors)
# PSoC™ 5, 3 & 1
# AIROC™ Bluetooth
# Non Volatile RAM (F-RAM & NVSRAM)
# USB EZ-PD™ Type-C
# CIPURSE™
# Low Noise Amplifiers
# Diodes & Thyristors (Si/SiC)
# Radar sensor
# DAVE™
# PSoC™ Creator & Designer
# Specialty Memory
# OPTIGA™ Connect
# CAPSENSE™ & MagSense
# RF Switches
# Smart Power Switches
# Angle (Magnetic sensor)
# Code Examples
# Wi-Fi Bluetooth for Linux
# SRAM
# Current (Magnetic sensor)
# Gate Driver ICs
# Community Translations
# LED Driver ICs
# MEMS microphones
# AURIX™ Development Studio
# Imagimob
# Pressure Sensors
# Intelligent Power Modules (IPM)
# XMC™
# Class D Audio Amplifier IC
# AURIX™
# TRAVEO™ T2G
# Speed (Magnetic sensor)
# Motor Control ICs
# Power Management ICs
# MOTIX™ MCU
# Legacy microcontrollers
# Battery Management ICs
# Contactless power and sensing ICs

# %% [markdown]
# # Read Input Data

# %% [markdown]
# According to different product, we have different input data. To simplify, we use "Instant Data Scraper" chrome extension to do data scraping from the community website. (https://chromewebstore.google.com/detail/instant-data-scraper/ofaokhiedipichpaobibbnahnkdoiiah)

# %%
df1 = pd.read_csv('data/PSoC6.csv')
df2 = pd.read_csv('data/Wi-Fi Combo.csv')
df3 = pd.read_csv('data/Nor Flash.csv')
df4 = pd.read_csv('data/USB low-full-high speed peripherals.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [56], in <cell line: 4>()
#       2 df2 = pd.read_csv('data/Wi-Fi Combo.csv')
#       3 df3 = pd.read_csv('data/Nor Flash.csv')
# ----> 4 df4 = pd.read_csv('data/USB low-full-high speed peripherals.csv')
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 5 fields in line 3, saw 13

# %%
df1.loc[:,['subject-link','truncated-body']] #PSoC6
# Out:
#                                            subject-link  \
# 0               使用PSoc 62系列板卡时遇到了无法烧录和调试的问题，似乎是flash的问题
# 1                                   PSoC6 CY8CPROTO-063
# 2     Encountering Issues with Programming and Debug...
# 3            SCB Managing Slave Select Peripheral Lines
# 4     How to properly use dma and spi together with ...
# ...                                                 ...
# 3336                                          Datasheet
# 3337                 what about the features of PSOC 6?
# 3338                  Does PSOC 6 support MESH network?
# 3339                                     Cortex M4 FPU?
# 3340                                                NaN
#
#                                          truncated-body
# 0     我的板卡型号是Psoc6-evaluationkit-062S2，在我按下板卡上的MODE按...
# 1     Hello, good afternoon, I am going to work on a...
# 2     Translated Content:\nBoard Model: Psoc6-evalua...
# 3     - Device Configurator 3.10.0.6117\n- 7e6892ee1...
# 4     We are having a problem communicating with two...
# ...                                                 ...
# 3336              Preliminary datasheet available yet ?
# 3337  It is glad to see PSOC6 released on the offici...
# 3338  The video on the official website what I see A...
# 3339  I have always associated the Cortex-M4 with a ...
# 3340                                                NaN
#
# [3341 rows x 2 columns]

# %%
df2.loc[:,['subject-link','truncated-body']] #Wi-Fi Combo
# Out:
#                                            subject-link  \
# 0                               Malloc is thread safe ?
# 1               CYW943907 - Amazon FreeRTOS OTA support
# 2     how to enable or disable the save restore feat...
# 3                                   HTTPS speed problem
# 4                                   Disable dns server.
# ...                                                 ...
# 3345  SPI port configuration for SFLASH on other tha...
# 3346  How do I port a WICED-SDK-1.x app to WICED-SDK...
# 3347            How do I avoid building the bootloader?
# 3348                    Welcome &amp; Forum Usage Notes
# 3349                                                NaN
#
#                                          truncated-body
# 0     Hello,\nI'm using WICED STUDIO 6.6. and CYW943...
# 1     Hi, Per Amazon doc, CYW943907AEVAL1F is not su...
# 2     when I read the register of CHIPCOMMON_SR_CONT...
# 3     Good afternoon. I am facing HTTPS speed issue ...
# 4     Hi, I have a Laird Sterling EWB. What I try to...
# ...                                                 ...
# 3345  [WICED-SDK-2.2.1, MCU: STM32F205]From what I s...
# 3346  I have an app that works with WICED_SDK-1.3, h...
# 3347  What is the correct way to build an applicatio...
# 3348  Welcome to the WICED Forum!We hope you find th...
# 3349                                                NaN
#
# [3350 rows x 2 columns]

# %%
df3.loc[:,['subject-link','truncated-body']] #Nor Flash
# Out:
#                                            subject-link  \
# 0     how to use or unprotect the highest address se...
# 1             S25FL256LAGNFM010 material specifications
# 2                       S29AL016J70TFN020 Thermal Data?
# 3                Where is the file ---- slld_fll_256l.h
# 4                   S29JL032J60TFI010 of Product Status
# ...                                                 ...
# 1840                                        关于fx3芯片的寄存器
# 1841                                        igbt module
# 1842                                 ゲートドライブ回路の推奨設計について
# 1843                              MOTIX 6EDL7141 issues
# 1844                             TLE5012B_E5000的SPI_SSC
#
#                                          truncated-body
# 0     Hi,\nIam using a  S70GL02GT11FHA010 NOR Flash....
# 1     I would like to know what the potting compound...
# 2     Hello,\nWe would like to use this memory: S29A...
# 3     A member from Infineon posted me a zip file re...
# 4     How is the production of S29JL032J60TFI010 pro...
# ...                                                 ...
# 1840  在ez-usb fx3芯片的technical reference manual中的chap...
# 1841  Good afternoon, would it be possible to replac...
# 1842  DCDCの設計を行っているのですが、車のレイアウトの関係で基板が２相でまたがってしまいます。...
# 1843  I'm currently working on motor driver wit usag...
# 1844  请教：\n我们想使用XMC4800和TLE5012B_E5000进行通讯，但我们在DAVE_...
#
# [1845 rows x 2 columns]

# %%
df4.loc[:,['subject-link','truncated-body']] #USB low-full-high speed peripherals
# Out:
#                                            subject-link  \
# 0                    CY7C65215, configuration image CRC
# 1        Arming of bulk/interrupt out endpoint in fx2lp
# 2            Pinout error on documentation of CY7C6514D
# 3                                  CY7C65210 TID Number
# 4          Setting up isochronous out endpoint in fx2lp
# ...                                                 ...
# 2729                   external RAM Selection for TC387
# 2730      Spice model incompatibility IMZA120R014M1H_L3
# 2731                          secure boot using slb9673
# 2732  (SDK 1.3.5) No "CyU3PDmaMultiChannelGetBuffer(...
# 2733  How fast can the FX3 transfer data in superspe...
#
#                                          truncated-body
# 0     From a linux system, I want to read back the c...
# 1     Hello,I am stuck at a point,in my application ...
# 2     Hi Infineon Community,\nI am reviewing the sec...
# 3         Hi,\nWhat is CY7C65210 TID number?\nBR\nEason
# 4     Hello,Can someone point me to examples codes f...
# ...                                                 ...
# 2729  We are looking for external RAM (around 2MB, p...
# 2730  Dear Infineon team,the spice model of the IMZA...
# 2731  Hi team, \nwe are using the slb9673 tpm2 chip ...
# 2732  Dear Support\n \nAs KBA231382, if all buffers ...
# 2733  Dear all,         We've observed the speed abo...
#
# [2734 rows x 2 columns]
